# %%
# !mkdir proto_resnet
# %cd proto_resnet
# Out:
# mkdir: cannot create directory ‘proto_resnet’: File exists
# /content/proto_resnet

# %%
# !git clone https://github.com/Henrymachiyu/ProtoViT.git
# Out:
# fatal: destination path 'ProtoViT' already exists and is not an empty directory.

# %%
# !git clone https://github.com/cyizhuo/CUB_200_2011_dataset.git
# Out:
# fatal: destination path 'CUB_200_2011_dataset' already exists and is not an empty directory.

# %%
# !mkdir -p ProtoViT/datasets/cub200_cropped/train_cropped
# !mkdir -p ProtoViT/datasets/cub200_cropped/test_cropped

# %%
# %cd ProtoViT
# Out:
# [Errno 2] No such file or directory: 'ProtoViT'
# /content/proto_resnet/ProtoViT

# %%
# !pip -q install torch torchvision
# !pip -q install -r requirements.txt
# !pip -q install timm==0.4.12
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 24.3 MB/s eta 0:00:00

# %%
# !python img_aug.py

# %%
from torchvision.datasets import ImageFolder

train_ds = ImageFolder("./datasets/cub200_cropped/train_cropped")
test_ds  = ImageFolder("./datasets/cub200_cropped/test_cropped")

print("Train images:", len(train_ds))
print("Test images :", len(test_ds))
print("Classes     :", len(train_ds.classes))
print("First class :", train_ds.classes[0])
